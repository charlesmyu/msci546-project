# %%
import pandas as pd
import csv
import os

# %%
df = pd.read_csv("./raw/census_starter.csv")
df.head()
# Out:
#    pct_bb_2017  pct_bb_2018  pct_bb_2019  pct_bb_2020  pct_bb_2021  cfips  \
# 0         76.6         78.9         80.6         82.7         85.5   1001
# 1         74.5         78.1         81.8         85.1         87.9   1003
# 2         57.2         60.4         60.5         64.6         64.6   1005
# 3         62.0         66.1         69.2         76.1         74.6   1007
# 4         65.8         68.5         73.0         79.6         81.0   1009
#
#    pct_college_2017  pct_college_2018  pct_college_2019  pct_college_2020  \
# 0              14.5              15.9              16.1              16.7
# 1              20.4              20.7              21.0              20.2
# 2               7.6               7.8               7.6               7.3
# 3               8.1               7.6               6.5               7.4
# 4               8.7               8.1               8.6               8.9
#
#    ...  pct_it_workers_2017  pct_it_workers_2018  pct_it_workers_2019  \
# ...

# %%
# Transform into 4 files (YEAR.csv)
years = ['2017', '2018', '2019', '2020']
columns = ['pct_bb_', 'pct_college_', 'pct_it_workers_', 'median_hh_inc_']
updated_columns = ['pct_broadband', 'pct_college', 'pct_in_it_industry', 'median_hh_inc']

for year in years:
    rename_dict = {}
    for idx, col in enumerate(columns):
        rename_dict[col + year] = updated_columns[idx]

    original_columns = ['cfips'] + [column + year for column in columns]
    temp = df.filter(items=original_columns)
    temp = temp.rename(columns=rename_dict)
    temp.to_csv('./parsed/' + year + '.csv', index=False)
